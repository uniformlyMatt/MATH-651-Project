# %% [markdown]
# # Show Edge Detection Result
# This is a notebook to show edge detection result, and also make graph for the final report.

# %%
from edge_prog_2d import *
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ## Read the Satellite Image

# %%
I = plt.imread('./png_satellite_image/6100_0_3_gray.png')
fig = plt.subplots(figsize=[12,8])
plt.imshow(I, cmap='gray')

# %%
N = 256
x1 = 300 
y1 = 1140
x2 = 2200
y2 = 2230
x3 = 1800
y3 = 350

I1 = I[x1:x1+N, y1:y1+N]
I1 = I1[:,:,1]
I2 = I[x2:x2+N, y2:y2+N]
I2 = I2[:,:,1]
I3 = I[x3:x3+N, y3:y3+N]
I3 = I3[:,:,1]

plt.imsave('./edge_data/image1.png', I1, cmap='gray')
plt.imsave('./edge_data/image2.png', I2, cmap='gray')
plt.imsave('./edge_data/image3.png', I3, cmap='gray')

# %%
I1.shape
# Out:
# (256, 256)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=[12,6]);
ax1.imshow(I1, cmap='gray')
ax1.set_title('Image 1')
ax1.set_xticks([]);
ax1.set_yticks([]);

ax2.imshow(I2, cmap='gray')
ax2.set_title('Image 2')
ax2.set_xticks([]);
ax2.set_yticks([]);

ax3.imshow(I3, cmap='gray')
ax3.set_title('Image 3')
ax3.set_xticks([]);
ax3.set_yticks([]);

# %% [markdown]
# ## Satellite Image Edge Detection
# Work flow:
# 1. Read the image data
# 2. Make a scale sequence
# 3. Do CWT on each scale, get E
# 4. Calculate Lipschite Exponent
#
# ### Image 1

# %%
scale = np.linspace(-6, -3, 16);
scale = 2**scale

E1 = cal_multi_edge(I1, scale)

a, ind, val, s = LE_2d(E1, scale, 0.1)

th = np.linspace(-0.6,-0.35,6)
Lip1 = np.ndarray([E1.shape[0], E1.shape[1], 6])
E_one1 = np.ndarray([E1.shape[0], E1.shape[1], 6])
E_val1 = np.ndarray([E1.shape[0], E1.shape[1], 6])
for i in range(6):
    Lip1[:,:,i], E_one1[:,:,i], E_val1[:,:,i] = ex_edge_by_Lip(E1, a, ind, th[i])
    
    L_name = './edge_data/image1_lip_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(L_name, Lip1[:,:,i], cmap='gray')
    Eone_name = './edge_data/image1_Eone_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(Eone_name, E_one1[:,:,i], cmap='gray')
    Eval_name = './edge_data/image1_Eval_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(Eval_name, E_val1[:,:,i], cmap='gray')
# Out:
# /Users/lida/Desktop/MATH-651-Project/edge_prog_2d.py:34: RuntimeWarning: divide by zero encountered in true_divide
#   A = V / H
# /Users/lida/Desktop/MATH-651-Project/edge_prog_2d.py:131: RuntimeWarning: divide by zero encountered in log2
#   val1[i,:] = np.log2(val[i,:])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(Lip1[:,:,i], cmap='gray')
    title = 'Image 1, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(E_val1[:,:,i], cmap='gray')
    title = 'Image 1, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(E_one1[:,:,i], cmap='gray')
    title = 'Image 1, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %% [markdown]
# ### Image 2

# %%
scale = np.linspace(-6, -3, 16);
scale = 2**scale

E2 = cal_multi_edge(I2, scale)

a, ind, val, s = LE_2d(E2, scale, 0.1)

th = np.linspace(-0.6,-0.35,6)
Lip2 = np.ndarray([E2.shape[0], E2.shape[1], 6])
E_one2 = np.ndarray([E2.shape[0], E2.shape[1], 6])
E_val2 = np.ndarray([E2.shape[0], E2.shape[1], 6])
for i in range(6):
    Lip2[:,:,i], E_one2[:,:,i], E_val2[:,:,i] = ex_edge_by_Lip(E2, a, ind, th[i])
    
    L_name = './edge_data/image2_lip_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(L_name, Lip2[:,:,i], cmap='gray')
    Eone_name = './edge_data/image2_Eone_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(Eone_name, E_one2[:,:,i], cmap='gray')
    Eval_name = './edge_data/image2_Eval_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(Eval_name, E_val2[:,:,i], cmap='gray')
# Out:
# /Users/lida/Desktop/MATH-651-Project/edge_prog_2d.py:34: RuntimeWarning: divide by zero encountered in true_divide
#   A = V / H
# /Users/lida/Desktop/MATH-651-Project/edge_prog_2d.py:131: RuntimeWarning: divide by zero encountered in log2
#   val1[i,:] = np.log2(val[i,:])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(Lip2[:,:,i], cmap='gray')
    title = 'Image 2, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(E_val2[:,:,i], cmap='gray')
    title = 'Image 2, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(E_one2[:,:,i], cmap='gray')
    title = 'Image 2, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %% [markdown]
# ### Image 3

# %%
scale = np.linspace(-6, -3, 16);
scale = 2**scale

E3 = cal_multi_edge(I3, scale)

a, ind, val, s = LE_2d(E3, scale, 0.1)

th = np.linspace(-0.6,-0.35,6)
Lip3 = np.ndarray([E3.shape[0], E3.shape[1], 6])
E_one3 = np.ndarray([E3.shape[0], E3.shape[1], 6])
E_val3 = np.ndarray([E3.shape[0], E3.shape[1], 6])
for i in range(6):
    Lip3[:,:,i], E_one3[:,:,i], E_val3[:,:,i] = ex_edge_by_Lip(E3, a, ind, th[i])
    
    L_name = './edge_data/image3_lip_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(L_name, Lip3[:,:,i], cmap='gray')
    Eone_name = './edge_data/image3_Eone_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(Eone_name, E_one3[:,:,i], cmap='gray')
    Eval_name = './edge_data/image3_Eval_' + str(i) + '_' + str(th[i]) + '.png'
    plt.imsave(Eval_name, E_val3[:,:,i], cmap='gray')
# Out:
# /Users/lida/Desktop/MATH-651-Project/edge_prog_2d.py:34: RuntimeWarning: divide by zero encountered in true_divide
#   A = V / H
# /Users/lida/Desktop/MATH-651-Project/edge_prog_2d.py:131: RuntimeWarning: divide by zero encountered in log2
#   val1[i,:] = np.log2(val[i,:])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(Lip3[:,:,i], cmap='gray')
    title = 'Image 3, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(E_val3[:,:,i], cmap='gray')
    title = 'Image 3, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(E_one3[:,:,i], cmap='gray')
    title = 'Image 3, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %% [markdown]
# ## Test a Square

# %%
N = 128 
g,t = gaus(N,0.8,1)
C = np.zeros([N,N])
C[N/4:3*N/4,N/4:3*N/4] = 1
G = np.zeros([N,N])
for i in range(N):
    G[:,i] = g
for i in range(N):
    G[i,:] = G[i,:] * g
G = G / np.max(G)
G[0:N/2,:] = 1
C = make_circle()
C = C * G

I4 = C
# Out:
# /Users/lida/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /Users/lida/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:11: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-a773a3b41647> in <module>()
#      10 G = G / np.max(G)
#      11 G[0:N/2,:] = 1
# ---> 12 C = make_circle()
#      13 C = C * G
#      14
#
# NameError: name 'make_circle' is not defined

# %%
plt.imshow(C)

# %%
scale = np.linspace(-6, -3, 16);
scale = 2**scale

E4 = cal_multi_edge(I4, scale)

a, ind, val, s = LE_2d(E4, scale, 0.1)

th = np.linspace(-1,1,6)
Lip4 = np.ndarray([E4.shape[0], E4.shape[1], 6])
E_one4 = np.ndarray([E4.shape[0], E4.shape[1], 6])
E_val4 = np.ndarray([E4.shape[0], E4.shape[1], 6])
for i in range(6):
    Lip4[:,:,i], E_one4[:,:,i], E_val4[:,:,i] = ex_edge_by_Lip(E4, a, ind, th[i])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(Lip4[:,:,i], cmap='gray')
    title = 'Image 3, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(E4[:,:,i], cmap='gray')
    title = 'Image 3, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
def make_circle():
    x = np.linspace(-63,64,128)
    y = np.linspace(-63,64,128)
    X, Y = np.meshgrid(x,y)
    C = np.zeros([128,128])
    for i in range(128):
        for j in range(128):
            xx = X[i,j]
            yy = Y[i,j]
            if (xx**2 + yy**2 < 32**2):
                C[i,j] = 1;
    C[64,:] = 1; C[:,64] = 1;
    return C
C = make_circle()
plt.imshow(C)

# %%
I4=C
scale = np.linspace(-6, -3, 16);
scale = 2**scale

E4 = cal_multi_edge(I4, scale)

a, ind, val, s = LE_2d(E4, scale, 0.1)

th = np.linspace(-1,1,6)
Lip4 = np.ndarray([E4.shape[0], E4.shape[1], 6])
E_one4 = np.ndarray([E4.shape[0], E4.shape[1], 6])
E_val4 = np.ndarray([E4.shape[0], E4.shape[1], 6])
for i in range(6):
    Lip4[:,:,i], E_one4[:,:,i], E_val4[:,:,i] = ex_edge_by_Lip(E4, a, ind, th[i])

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[14,7])
for ax,i in zip(axes.flat, range(6)):
    ax.imshow(Lip4[:,:,i], cmap='gray')
    title = 'Image 3, LE <'
    title += str(th[i])
    ax.set_title(title)
    ax.set_xticks([])
    ax.set_yticks([])
